# %%
import random 

def get_word(): 
      
    words = ['apple', 'orange', 'watermelon', 'guava', 'obama', 'trump', 'nccu', 'cheerleading', 'university']
    
    return random.choice(words) 
  
myword = get_word() 
  
for i in myword: 
    print("*", end = " ") 

l = len(myword) 
print("\nWord has %d letters" %l) 
  
def check(myword, your_word, guess1): 
    status = '' 
    matches = 0
      
    for letter in myword: 
        if letter in your_word: 
            status += letter 
        else: 
            status += '*'
        if letter == guess1: 
            matches += 1
              
    if matches > 1: 
        print(matches, guess1) 
          
    elif matches == 1: 
        print(guess1) 
    return status 
  
def game(): 
    guess = 0
    guessed = False
    your_word = [] 
    turns = len(myword) + 1
    turns1 = turns 
      
    print("Total turns: ", turns) 
    while guess < turns1: 
        guess1 = input("Enter your guess: ") 
        turns -= 1
        print("Turns left", turns) 

        if guess1 in your_word: 
            print("You already guessed") 
        elif len(guess1) == 1: 
            your_word.append(guess1) 
            result = check(myword, your_word, guess1) 
            if result == myword: 
                guessed = True
                print("You won " + name) 
                print(myword) 
            else: 
                print(result) 
        else: 
            print("Invalid entry") 
        guess += 1
    if guess == turns1: 
        print("Word is:") 
        print(myword) 

game()
# Out:
# * * * * * * * * * *
# Word has 10 letters
# Total turns:  11
# Enter your guess: w
# Turns left 10
# **********
# Enter your guess: g
# Turns left 9
# **********
# Enter your guess: t
# Turns left 8
# t
# ********t*
# Enter your guess: a
# Turns left 7
# ********t*
# Enter your guess: e
# Turns left 6
# e
# ****e***t*
# Enter your guess: r
# Turns left 5
# r
# ****er**t*
# Enter your guess: m
# Turns left 4
# ****er**t*
# Enter your guess: l
# Turns left 3
# ****er**t*
# Enter your guess: o
# Turns left 2
# ****er**t*
# Enter your guess: n
# Turns left 1
# n
# *n**er**t*
# Enter your guess: watermelon
# Turns left 0
# Invalid entry
# Word is:
# university
